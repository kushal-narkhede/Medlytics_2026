# %% [markdown]
# # Neural Network Exercise
#
# In this Exercise Notebook you will be building your own artificial neural network and seeing how adding different types of layers can affect the validation/testing accuracy. This is based off of the Simple Neural Network with Keras tutorial, so you can reference that for further explanations as well.

# %%
import os
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.utils import shuffle
from keras.models import Sequential
from keras.layers import Dense
import tensorflow as tf

# %%
os.system('wget https://raw.githubusercontent.com/BeaverWorksMedlytics2020/Data_Public/master/NotebookExampleData/Week2/spoken_digit_manual_features.csv')
# Out:
# 0

# %% [markdown]
# ## Load Training Data and Pre-processed Features
#
# Your goal is to build a neural network that learns to classify which of the 5 speakers is recorded in a signal sample. Your prediction will be based off of features we've already pre-extracted for you and put into this CSV: spectral centroid `SC`, spectral flatness `SF`, and maximum frequency `MF`.

# %%
# Load csv containing raw data, labels, and pre-processed features
spoken_df = pd.read_csv('spoken_digit_manual_features.csv', index_col = 0)
print(spoken_df.head(10))
print('\n')

# Set speakers
speakers = set(spoken_df['speaker'])
print(f'There are {len(speakers)} unique speakers in the dataset')
# Out:
#                 file  digit   speaker  trial           SC        SF  \
# 0   5_yweweler_8.wav      5  yweweler      8  1029.497959  0.397336
# 1    3_george_49.wav      3    george      4  1881.296834  0.387050
# 2  9_yweweler_44.wav      9  yweweler      4  1093.951856  0.394981
# 3  8_yweweler_33.wav      8  yweweler      3  1409.543285  0.487496
# 4      7_theo_34.wav      7      theo      3   887.361601  0.396825
# 5   1_jackson_45.wav      1   jackson      4  1007.568129  0.324100
# 6  6_yweweler_18.wav      6  yweweler      1  1286.701352  0.498813
# 7    9_george_35.wav      9    george      3  1405.092061  0.353083
# 8   9_jackson_32.wav      9   jackson      3  1172.899961  0.477907
# 9    8_george_26.wav      8    george      2  1959.977577  0.462901
#
#            MF
# 0  745.878340
# 1  323.943662
# 2  244.648318
# 3  392.350401
# 4  130.640309
# 5  216.306156
# 6  400.715564
# 7  447.239693
# 8  114.892780
# 9  320.537966
#
#
# There are 5 unique speakers in the dataset

# %% [markdown]
# Converting labels to "onehot" vectors:

# %%
# Make dictionary to convert from speaker names to indices
name2int_dict = {name: ind for (ind, name) in enumerate(set(spoken_df['speaker']))}

y_labels = spoken_df['speaker']
# Set y_labels to be indices of speaker
y_labels = [name2int_dict[name] for name in y_labels]

# %% [markdown]
# Standardize data and split into train, validation, and test sets:

# %%
# Downselect to only the 3 columns of the dataset we are learning from, aka the features
X_data = spoken_df[['SC', 'SF', 'MF']].to_numpy()

# Decide how large to make validation and test sets
n_val = 250
n_test = 250

# Shuffle data before partitioning
X_data, y_labels = shuffle(X_data, y_labels, random_state = 25)

# Partition
X_data_test, y_labels_test = X_data[:n_test,:], y_labels[:n_test]
X_data_val, y_labels_val = X_data[n_test:n_test+n_val,:], y_labels[n_test:n_test+n_val]
X_data_train, y_labels_train = X_data[n_test+n_val:,:], y_labels[n_test+n_val:]

# Scale data
scaler = StandardScaler()
X_data_train=scaler.fit_transform(X_data_train)
X_data_val = scaler.transform(X_data_val)
X_data_test = scaler.transform(X_data_test)

# Convert labels to onehot
y_labels_train = tf.keras.utils.to_categorical(y_labels_train, 5)
y_labels_val =  tf.keras.utils.to_categorical(y_labels_val, 5)
y_labels_test =  tf.keras.utils.to_categorical(y_labels_test, 5)

training_set = tf.data.Dataset.from_tensor_slices((X_data_train, y_labels_train))

# %% [markdown]
# ## Aditional Layers
#
# Before you get to writing your own neural network we'll show you some examples of additional layers you can potetially add that we didn't go over in the tutorial. After reading over our explanations/example code and going through documentation you'll be testing some of these out by putting together a neural network yourself.

# %% [markdown]
# ### Dropout Layers
#
# Dropout layers randomly omit, or drop, some elements of the output vector from the layer, which helps prevent overfitting and can improve the generalization of your neural network. The dropout rate can be any number between 0 and 1.
#
# https://www.tensorflow.org/api_docs/python/tf/keras/layers/Dropout
#
# ```python
# # Example
# d_r = 0.6
# tf.keras.layers.Dropout(rate=d_r)
# ```

# %% [markdown]
# ### Pooling Layers
#
# A pooling layer reduces dimensionality (reducing the size of each feature map) and "compresses" information by combining several output elements. Two common functions used for pooling are:
# - Average pooling: calculating the average value for each patch on the feature map
# - Max pooling: calculating the maximum value for each patch of the feature map
#
# https://www.tensorflow.org/api_docs/python/tf/keras/layers/MaxPool1D
#
# ```python
# # Example
# tf.keras.layers.MaxPool1D(pool_size=1)
# ```

# %% [markdown]
# ### Activation Layers/Functions
#
# An activation function looks at each "neuron" in your neural network and determines whether it should be activated (fired) or not, based on the relevancy of the neuron's input to the model’s predictions. Some different activation functions you could look at are:
# - softmax https://www.tensorflow.org/api_docs/python/tf/keras/layers/Softmax
# - sigmoid https://www.tensorflow.org/api_docs/python/tf/keras/activations/sigmoid
# - softplus https://www.tensorflow.org/api_docs/python/tf/keras/activations/softplus
# - relu https://www.tensorflow.org/api_docs/python/tf/keras/layers/ReLU
#
# ```python
# # Example
# tf.keras.layers.Softmax()
# ```

# %% [markdown]
# ### Optimation Functions
#
# Optimation functions
# - Adam https://www.tensorflow.org/api_docs/python/tf/keras/optimizers/Adam
#   - Adam is computationally efficient, has little memory requirement, and is well suited for problems that are large in terms of data/parameter.
# - Adagrad https://www.tensorflow.org/api_docs/python/tf/keras/optimizers/Adagrad
#   - Adagrad is an optimizer that is best used for sparse data. Some of its benefits are that it converges more quickly and doesn't need manual adjustment of the hyperparameter "learning rate".
# - SGD https://www.tensorflow.org/api_docs/python/tf/keras/optimizers/SGD
#   - SGD is a stochastic gradient descent and momentum optimizer. SGD essentially helps gradient vectors move down loss functions towards the minimum point, leading to faster "converging".
# - RMSprop https://keras.io/api/optimizers/rmsprop/
#   - As you may already know, the learning rate regulates how much the model
# can change based on the estimated error (which occurs every time the model's weights are updated). Instead of treating the learning rate as a hyperparamter, RMSprop is an optimization technique that uses relies on a changing, adaptive learning rate.
#
# ```python
# # Example code
# l_r = .001
# tf.keras.optimizers.SGD(learning_rate=l_r)
# ```

# %% [markdown]
# ## Putting Together Your Neural Network
#
# Now you will experiment with adding different layers to your neural network. We've added some guiding comments to give you a place to start and test out, but we also strongly encourage you to go through all the documetation and do some googling as well!

# %%
# Once you've gone through all the tests play around with these rate values to see if you can increase your accuracy
l_r = 0.01   # learning rate (tutorial used 0.01)
d_r = 0.2    # dropout rate (0.6 is often too strong for this small net)

model = tf.keras.Sequential()
model.add(tf.keras.layers.Dense(8, input_shape=(3,), activation='relu'))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# ### Test 1

# %%
# Run this cell as it is
model.add(tf.keras.layers.Dense(8))
model.add(tf.keras.layers.Dense(8))

# output dimension needs to be number of classes in order for each to get a score
model.add(tf.keras.layers.Dense(5))

# Now skip down to the section that compiles and trains your model and run those cells.
# Check the pseudo-test accuracy and see how well the bare minimum performed.

# %% [markdown]
# ### Test 2

# %%
# Hidden layers with ReLU activation
model.add(tf.keras.layers.Dense(8, activation='relu'))
model.add(tf.keras.layers.Dense(8, activation='relu'))

# Output: 5 classes → Softmax turns scores into probabilities
model.add(tf.keras.layers.Dense(5, activation='softmax'))

# Now skip down to the section that compiles and trains your model and re-run those cells.
# What do you notice about the testing/Validation accuracy after Test 2 in comparison to Test 1?

# %% [markdown]
# ### Test 3

# %%
# Add activation layer here
model.add(tf.keras.layers.Dense(8, activation='relu'))
# Add activation layer here
model.add(tf.keras.layers.Dropout(rate=d_r))   
# Add activation layer here 
model.add(tf.keras.layers.Dense(8, activation='relu'))

# output dimension needs to be number of classes in order for each to get a score
model.add(tf.keras.layers.Dense(5, activation='softmax'))

# Add dropout layer here

# Now skip down to the section that compiles and trains your model and re-run those cells.
# What do you notice about the testing/Validation accuracy after Test 2 in comparison to Test 1 & 2?

# %% [markdown]
# ### Test 4
#
# Now go back down to the cell where you compiled your model, and this time change the optimizer. It's been set to Adam by default but as we showed you above, there are other functions that you can test out.

# %% [markdown]
# ## Compiling and Training Your Model

# %%
model.compile(loss = tf.keras.losses.categorical_crossentropy, 
              optimizer = tf.keras.optimizers.SGD(learning_rate=l_r),
              metrics = ['accuracy'])

# %% [markdown]
# Fit Model to Data, Specify Number of Epochs and Batch Size:

# %%
EPOCHS = 50
batch_size = 100

training_set = training_set.batch(batch_size) #set batch size

for epoch in range(EPOCHS):
    for signals, labels in training_set:
        tr_loss, tr_accuracy = model.train_on_batch(signals, labels)
    val_loss, val_accuracy = model.evaluate(X_data_val, y_labels_val)
    print(('Epoch #%d\t Training Loss: %.2f\tTraining Accuracy: %.2f\t'
         'Validation Loss: %.2f\tValidation Accuracy: %.2f')
         % (epoch + 1, tr_loss, tr_accuracy,
         val_loss, val_accuracy))
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.1800 - loss: 4.0291
# Epoch #1	 Training Loss: 4.64	Training Accuracy: 0.17	Validation Loss: 4.03	Validation Accuracy: 0.18
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.1960 - loss: 3.7527
# Epoch #2	 Training Loss: 4.06	Training Accuracy: 0.18	Validation Loss: 3.75	Validation Accuracy: 0.20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.1760 - loss: 2.7873
# Epoch #3	 Training Loss: 3.52	Training Accuracy: 0.18	Validation Loss: 2.79	Validation Accuracy: 0.18
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.1680 - loss: 2.1328
# Epoch #4	 Training Loss: 2.51	Training Accuracy: 0.16	Validation Loss: 2.13	Validation Accuracy: 0.17
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.1520 - loss: 2.4789
# Epoch #5	 Training Loss: 2.29	Training Accuracy: 0.15	Validation Loss: 2.48	Validation Accuracy: 0.15
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.1440 - loss: 2.2083
# Epoch #6	 Training Loss: 2.30	Training Accuracy: 0.15	Validation Loss: 2.21	Validation Accuracy: 0.14
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.1560 - loss: 2.2331
# Epoch #7	 Training Loss: 2.05	Training Accuracy: 0.14	Validation Loss: 2.23	Validation Accuracy: 0.16
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.1400 - loss: 1.8193
# Epoch #8	 Training Loss: 1.89	Training Accuracy: 0.13	Validation Loss: 1.82	Validation Accuracy: 0.14
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.1160 - loss: 2.1486
# Epoch #9	 Training Loss: 1.83	Training Accuracy: 0.13	Validation Loss: 2.15	Validation Accuracy: 0.12
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.1160 - loss: 2.0778
# Epoch #10	 Training Loss: 2.21	Training Accuracy: 0.13	Validation Loss: 2.08	Validation Accuracy: 0.12
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.1840 - loss: 2.0006
# Epoch #11	 Training Loss: 2.22	Training Accuracy: 0.16	Validation Loss: 2.00	Validation Accuracy: 0.18
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.1880 - loss: 2.1433
# Epoch #12	 Training Loss: 2.26	Training Accuracy: 0.18	Validation Loss: 2.14	Validation Accuracy: 0.19
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.1880 - loss: 2.0334
# Epoch #13	 Training Loss: 2.19	Training Accuracy: 0.19	Validation Loss: 2.03	Validation Accuracy: 0.19
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.1840 - loss: 1.8715
# Epoch #14	 Training Loss: 2.05	Training Accuracy: 0.19	Validation Loss: 1.87	Validation Accuracy: 0.18
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.1760 - loss: 1.7898
# Epoch #15	 Training Loss: 1.94	Training Accuracy: 0.19	Validation Loss: 1.79	Validation Accuracy: 0.18
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.1760 - loss: 1.7793
# Epoch #16	 Training Loss: 1.88	Training Accuracy: 0.18	Validation Loss: 1.78	Validation Accuracy: 0.18
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.1760 - loss: 1.7265
# Epoch #17	 Training Loss: 1.87	Training Accuracy: 0.18	Validation Loss: 1.73	Validation Accuracy: 0.18
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.1760 - loss: 1.7169
# Epoch #18	 Training Loss: 1.82	Training Accuracy: 0.18	Validation Loss: 1.72	Validation Accuracy: 0.18
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.1840 - loss: 1.7077
# Epoch #19	 Training Loss: 1.80	Training Accuracy: 0.18	Validation Loss: 1.71	Validation Accuracy: 0.18
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.1520 - loss: 1.7694
# Epoch #20	 Training Loss: 1.81	Training Accuracy: 0.17	Validation Loss: 1.77	Validation Accuracy: 0.15
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.1520 - loss: 1.8334
# Epoch #21	 Training Loss: 1.85	Training Accuracy: 0.14	Validation Loss: 1.83	Validation Accuracy: 0.15
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.1320 - loss: 1.8325
# Epoch #22	 Training Loss: 1.82	Training Accuracy: 0.13	Validation Loss: 1.83	Validation Accuracy: 0.13
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.1200 - loss: 1.7743
# Epoch #23	 Training Loss: 1.81	Training Accuracy: 0.12	Validation Loss: 1.77	Validation Accuracy: 0.12
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.1200 - loss: 1.7228
# Epoch #24	 Training Loss: 1.84	Training Accuracy: 0.11	Validation Loss: 1.72	Validation Accuracy: 0.12
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.1280 - loss: 1.7186
# Epoch #25	 Training Loss: 1.84	Training Accuracy: 0.11	Validation Loss: 1.72	Validation Accuracy: 0.13
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.1640 - loss: 1.8065
# Epoch #26	 Training Loss: 1.83	Training Accuracy: 0.12	Validation Loss: 1.81	Validation Accuracy: 0.16
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.1720 - loss: 1.9269
# Epoch #27	 Training Loss: 1.93	Training Accuracy: 0.15	Validation Loss: 1.93	Validation Accuracy: 0.17
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.1320 - loss: 1.8300
# Epoch #28	 Training Loss: 1.87	Training Accuracy: 0.13	Validation Loss: 1.83	Validation Accuracy: 0.13
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.1320 - loss: 1.8111
# Epoch #29	 Training Loss: 1.80	Training Accuracy: 0.11	Validation Loss: 1.81	Validation Accuracy: 0.13
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.1360 - loss: 1.9249
# Epoch #30	 Training Loss: 1.82	Training Accuracy: 0.11	Validation Loss: 1.92	Validation Accuracy: 0.14
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.1320 - loss: 1.9399
# Epoch #31	 Training Loss: 1.84	Training Accuracy: 0.11	Validation Loss: 1.94	Validation Accuracy: 0.13
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.1400 - loss: 1.8248
# Epoch #32	 Training Loss: 1.81	Training Accuracy: 0.11	Validation Loss: 1.82	Validation Accuracy: 0.14
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.1360 - loss: 1.9407
# Epoch #33	 Training Loss: 1.82	Training Accuracy: 0.12	Validation Loss: 1.94	Validation Accuracy: 0.14
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.1360 - loss: 1.8093
# Epoch #34	 Training Loss: 1.83	Training Accuracy: 0.11	Validation Loss: 1.81	Validation Accuracy: 0.14
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.1520 - loss: 1.7913
# Epoch #35	 Training Loss: 1.81	Training Accuracy: 0.12	Validation Loss: 1.79	Validation Accuracy: 0.15
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.1560 - loss: 1.8457
# Epoch #36	 Training Loss: 1.77	Training Accuracy: 0.12	Validation Loss: 1.85	Validation Accuracy: 0.16
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.1480 - loss: 1.7073
# Epoch #37	 Training Loss: 1.78	Training Accuracy: 0.12	Validation Loss: 1.71	Validation Accuracy: 0.15
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.1480 - loss: 1.8830
# Epoch #38	 Training Loss: 1.78	Training Accuracy: 0.12	Validation Loss: 1.88	Validation Accuracy: 0.15
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.1480 - loss: 1.8857
# Epoch #39	 Training Loss: 1.77	Training Accuracy: 0.12	Validation Loss: 1.89	Validation Accuracy: 0.15
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.1520 - loss: 1.8231
# Epoch #40	 Training Loss: 1.78	Training Accuracy: 0.12	Validation Loss: 1.82	Validation Accuracy: 0.15
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.1560 - loss: 1.7302
# Epoch #41	 Training Loss: 1.81	Training Accuracy: 0.12	Validation Loss: 1.73	Validation Accuracy: 0.16
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.1480 - loss: 1.7279
# Epoch #42	 Training Loss: 1.80	Training Accuracy: 0.12	Validation Loss: 1.73	Validation Accuracy: 0.15
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.1480 - loss: 1.7232
# Epoch #43	 Training Loss: 1.79	Training Accuracy: 0.12	Validation Loss: 1.72	Validation Accuracy: 0.15
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.1320 - loss: 1.7092
# Epoch #44	 Training Loss: 1.80	Training Accuracy: 0.12	Validation Loss: 1.71	Validation Accuracy: 0.13
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.1440 - loss: 1.7900
# Epoch #45	 Training Loss: 1.84	Training Accuracy: 0.12	Validation Loss: 1.79	Validation Accuracy: 0.14
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.1600 - loss: 1.7810
# Epoch #46	 Training Loss: 1.87	Training Accuracy: 0.13	Validation Loss: 1.78	Validation Accuracy: 0.16
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.1160 - loss: 2.0014
# Epoch #47	 Training Loss: 1.88	Training Accuracy: 0.12	Validation Loss: 2.00	Validation Accuracy: 0.12
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.1160 - loss: 1.8479
# Epoch #48	 Training Loss: 1.89	Training Accuracy: 0.12	Validation Loss: 1.85	Validation Accuracy: 0.12
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.1320 - loss: 1.9971
# Epoch #49	 Training Loss: 1.85	Training Accuracy: 0.12	Validation Loss: 2.00	Validation Accuracy: 0.13
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.1280 - loss: 2.3051
# Epoch #50	 Training Loss: 2.43	Training Accuracy: 0.16	Validation Loss: 2.31	Validation Accuracy: 0.13

# %%
#Check Performance on Test Set
test_loss, test_accuracy = model.evaluate(X_data_test, y_labels_test)
# Out:
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.1562 - loss: 2.9088
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.1360 - loss: 2.7958

# %% [markdown]
# Now modify the existing model even more, and try to find the highest and appropriate testing and validation accuracy!
